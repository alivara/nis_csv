# %% [markdown]
# ## Load the CSV file and pandas library
# for read CSV file in pandas we use 'pd.read_csv('file name and location', index_col= 0 or 1)'
# and printing CSV file by '.head()'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('nis.csv',index_col=0)

df.head()
# Out:
#    SEQNUMC  SEQNUMHH  PDAT    PROVWT_D     RDDWT_D  STRATUM  YEAR  AGECPOXR  \
# 1   128521     12852     2         NaN  235.916956     1031  2017       NaN
# 2    10741      1074     2         NaN  957.353840     1068  2017       NaN
# 3   220011     22001     2         NaN  189.611299     1050  2017       NaN
# 4    86131      8613     1  675.430817  333.447418     1040  2017       NaN
# 5   227141     22714     1  482.617748  278.768063     1008  2017       NaN
#
#    HAD_CPOX  AGEGRP  ...  XVRCTY2  XVRCTY3  XVRCTY4  XVRCTY5  XVRCTY6  \
# 1         2       1  ...                        NaN      NaN      NaN
# 2         2       1  ...                        NaN      NaN      NaN
# 3         2       3  ...                        NaN      NaN      NaN
# 4         2       1  ...                        NaN      NaN      NaN
# 5         2       1  ...                        NaN      NaN      NaN
#
#    XVRCTY7  XVRCTY8  XVRCTY9  INS_STAT2_I  INS_BREAK_I
# ...

# %%
df_copy = df.copy()
df.describe()
# Out:
#              SEQNUMC      SEQNUMHH          PDAT      PROVWT_D       RDDWT_D  \
# count   28465.000000  28465.000000  28465.000000  15333.000000  28465.000000
# mean   136341.024697  13633.998033      1.461338    376.816991    202.976811
# std     78822.308954   7882.230931      0.498512    646.828310    326.449265
# min        11.000000      1.000000      1.000000      3.174044      2.895375
# 25%     68071.000000   6807.000000      1.000000     76.216327     44.494731
# 50%    136421.000000  13642.000000      1.000000    195.015630    113.260066
# 75%    204521.000000  20452.000000      2.000000    456.216316    250.143911
# max    272671.000000  27267.000000      2.000000  11555.055610   6240.054554
#
#             STRATUM     YEAR    AGECPOXR      HAD_CPOX        AGEGRP  ...  \
# count  28465.000000  28465.0  390.000000  28465.000000  28465.000000  ...
# mean    1960.210891   2017.0    2.448718      2.272756      2.109854  ...
# ...

# %% [markdown]
# ## Clean the titles and indexing

# %%
cols = list(df_copy.columns)
cols = [i.lower().strip() for i in cols]
df_copy.columns = cols
df_copy


##  or using code below for clean spaces
#df_copy = df_copy.rename(mapper=str.strip, axis='columns')
# Out:
#        seqnumc  seqnumhh  pdat    provwt_d     rddwt_d  stratum  year  \
# 1       128521     12852     2         NaN  235.916956     1031  2017
# 2        10741      1074     2         NaN  957.353840     1068  2017
# 3       220011     22001     2         NaN  189.611299     1050  2017
# 4        86131      8613     1  675.430817  333.447418     1040  2017
# 5       227141     22714     1  482.617748  278.768063     1008  2017
# ...        ...       ...   ...         ...         ...      ...   ...
# 28461    19141      1914     2         NaN   21.188088     2062  2017
# 28462   121401     12140     2         NaN   26.503010     2004  2017
# 28463   128831     12883     2         NaN   27.520652     2004  2017
# 28464    82921      8292     2         NaN   22.390587     2062  2017
# 28465   244621     24462     2         NaN   27.520652     2004  2017
#
#        agecpoxr  had_cpox  agegrp  ...  xvrcty2  xvrcty3  xvrcty4  xvrcty5  \
# ...

# %% [markdown]
# ## Mother Education
# by reading data file of CSV file we will find out that data about mother's education is stored in 'EDUC1'
# and by using '.set()' we will find the unique parameters of 'EDUC1'

# %%
for i in df.columns:
    if i == 'EDUC1':
        print("yes")
print(set(df['EDUC1']))
# or df['EDUC1'].unique()
# Out:
# yes
# {1, 2, 3, 4}

# %%
#df = pd.read_csv('assets/NISPUF17.csv', index_col=0)
    
EDUC1 = df['EDUC1'].value_counts(normalize=True)
#EDUC1
EDUC1_dic ={"less than high school":EDUC1.iloc[3],
            "high school":EDUC1.iloc[2],
            "more than high school but not college":EDUC1.iloc[1],
            "college":EDUC1.iloc[0]}
EDUC1_dic
# Out:
# {'less than high school': 0.10202002459160373,
#  'high school': 0.172352011241876,
#  'more than high school but not college': 0.24588090637625154,
#  'college': 0.47974705779026877}

# %% [markdown]
# ## Influenza vaccines
# the average number of influenza vaccines for those children we know received breastmilk as a child and those who know did not

# %% [markdown]
# now we can see the unique parameters in "P_NUMFLU"

# %%
for i in df.columns:
    if i == "P_NUMFLU":
        print("yes")
print(set(df['EDUC1']))
# or df['EDUC1'].unique()
# Out:
# yes
# {1, 2, 3, 4}

# %%
df1 = df[df["CBF_01"] == 1]
df2 = df[df["CBF_01"] == 2]
    
print(df1["P_NUMFLU"].mean(),df2["P_NUMFLU"].mean())
# Out:
# 1.8799187420058687 1.5963945918878317

# %% [markdown]
# ## Ratio
# the ratio of the number of children who contracted chickenpox but were vaccinated against it (at least one varicella dose) versus those who were vaccinated but did not contract chicken pox.

# %%
for i in df.columns:
    if i == "CBF_01":
        print("yes")
print(set(df['CBF_01']))
# or df['EDUC1'].unique()
# Out:
# yes
# {1, 2, 99, 77}

# %% [markdown]
# ## P_NUMVRC
# now we can see the unique parameters in "P_NUMFLU"

# %%
for i in df.columns:
    if i == "P_NUMVRC":
        print("yes")
print(set(df['P_NUMVRC']))
# Out:
# yes
# ...

# %% [markdown]
# As you see the are 'nan' parameters in "P_NUMVRC"
# so we will use .dropna() for cleanning

# %%
df['P_NUMVRC'].dropna()
# Out:
# 4        1.0
# 5        0.0
# 7        1.0
# 8        0.0
# 9        0.0
#         ...
# 28447    1.0
# 28448    1.0
# 28450    1.0
# 28453    1.0
# 28455    1.0
# Name: P_NUMVRC, Length: 15333, dtype: float64

# %% [markdown]
# But there is an easier way :)

# %%
hdyp = df[(df["HAD_CPOX"] ==1) & (df["P_NUMVRC"] >= 1)]
hdnp = df[(df["HAD_CPOX"] ==2) & (df["P_NUMVRC"] >= 1)]

m_ratio_p = len(hdyp[hdyp["SEX"] == 1])/len(hdnp[hdnp["SEX"] == 1])
f_ratio_p = len(hdyp[hdyp["SEX"] == 2])/len(hdnp[hdnp["SEX"] == 2])
print(f"male ratio = {m_ratio_p} and female ration = {f_ratio_p}")
# Out:
# male ratio = 0.009675583380762664 and female ration = 0.0077918259335489565

# %% [markdown]
# by using & in that code and showing the parameters its gonan be a king of cleaning.

# %% [markdown]
# but if you want to clean the columns you can use below code

# %%
df = df[['HAD_CPOX', 'SEX', 'P_NUMVRC']].dropna()
df[['HAD_CPOX', 'SEX', 'P_NUMVRC']]
# Out:
#        HAD_CPOX  SEX  P_NUMVRC
# 4             2    2       1.0
# 5             2    2       0.0
# 7             2    2       1.0
# 8             2    2       0.0
# 9             1    1       0.0
# ...         ...  ...       ...
# 28447         2    2       1.0
# 28448         2    1       1.0
# 28450         2    1       1.0
# 28453         2    2       1.0
# 28455         2    2       1.0
#
# [15333 rows x 3 columns]
